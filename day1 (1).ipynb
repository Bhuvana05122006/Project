# %%
name="Bhuvaneswari"
age=25
CGPA=8.5
placed=False
print("Student name:",name)
print("Age:",age)
print("CGPA:",CGPA)
print("plased:",placed)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
# Out:
# Student name: Bhuvaneswari
# Age: 25
# CGPA: 8.5
# plased: False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name="Bhuvana"
print(len(name))
# Out:
# 7

# %%
name=["Bhuvana","sangari","kaviya"]
name.append("nilla")
mark=[50,48,80]
print(name)
print(marks[2])
print(len(name))
print(len(marks))
# Out:
# ['Bhuvana', 'sangari', 'kaviya', 'nilla']
# 30
# 4
# 4

# %%
days=["Monday","Tuesday","Wednesday"]
print(days[1])
# Out:
# Tuesday

# %%
student={
    "name":"Bhuvaneswari",
    "age":20
}
print(student)
# Out:
# {'name': 'Bhuvaneswari', 'age': 20}

# %%
import numpy as np
marks=np.array([80,48,30,90])
print(marks)
# Out:
# [80 48 30 90]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([5,6,7])
print(a+b)
# Out:
# [ 6  8 10]
